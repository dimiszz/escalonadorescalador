# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("out.csv")

print(data)

# cutuvelo
# Out:
#     MEDIA_TROCAS  MEDIA_INSTRUCOES  QUANTUMS
# 0           13.8          1.000000         1
# 1            7.8          1.759494         2
# 2            5.8          2.355932         3
# 3            5.1          2.673077         4
# 4            4.3          3.159091         5
# 5            4.0          3.390244         6
# 6            3.7          3.657895         7
# 7            3.7          3.657895         8
# 8            3.6          3.756757         9
# 9            3.6          3.756757        10
# 10           3.4          3.971429        11
# 11           3.4          3.971429        12
# 12           3.4          3.971429        13
# 13           3.3          4.088235        14
# 14           3.3          4.088235        15
# 15           3.3          4.088235        16
# 16           3.3          4.088235        17
# 17           3.3          4.088235        18
# 18           3.3          4.088235        19
# 19           3.3          4.088235        20
# ...

# %%
plt.plot(data['QUANTUMS'], data['MEDIA_TROCAS'])
plt.show()

# %%
plt.plot(data['QUANTUMS'], data['MEDIA_INSTRUCOES'])

plt.show()
